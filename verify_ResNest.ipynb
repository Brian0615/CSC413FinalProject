# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install torch==1.4.0 torchvision==0.5.0 ninja torch-encoding
# Out:
# ...
#      |██████████████████████████████  | 704.5MB 1.5MB/s eta 0:00:33ERROR: Exception:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/pip/_vendor/urllib3/response.py", line 425, in _error_catcher
#     yield
#   File "/usr/local/lib/python3.7/dist-packages/pip/_vendor/urllib3/response.py", line 507, in read
#     data = self._fp.read(amt) if not fp_closed else b""
#   File "/usr/local/lib/python3.7/dist-packages/pip/_vendor/cachecontrol/filewrapper.py", line 62, in read
#     data = self.__fp.read(amt)
#   File "/usr/lib/python3.7/http/client.py", line 461, in read
#     n = self.readinto(b)
#   File "/usr/lib/python3.7/http/client.py", line 505, in readinto
#     n = self.fp.readinto(b)
#   File "/usr/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
#   File "/usr/lib/python3.7/ssl.py", line 1071, in recv_into
#     return self.read(nbytes, buffer)
#   File "/usr/lib/python3.7/ssl.py", line 929, in read
# ...

# %%
# %cd /content/
# !git clone https://github.com/zhanghang1989/PyTorch-Encoding
# %cd /content/PyTorch-Encoding/
# !python setup.py clean
# !python setup.py install
# !pip install git+https://github.com/zhanghang1989/PyTorch-Encoding/
# !pip install git+https://github.com/facebookresearch/fvcore.git
# Out:
# /content
# Cloning into 'PyTorch-Encoding'...
# remote: Enumerating objects: 1801, done.
# remote: Counting objects: 100% (49/49), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 1801 (delta 19), reused 42 (delta 19), pack-reused 1752
# Receiving objects: 100% (1801/1801), 21.20 MiB | 27.37 MiB/s, done.
# Resolving deltas: 100% (986/986), done.
# /content/PyTorch-Encoding
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
# -- Building version 1.2.2b20210421
# c++:  ['/content/PyTorch-Encoding/encoding/lib/cpu/nms_cpu.cpp', '/content/PyTorch-Encoding/encoding/lib/cpu/encoding_cpu.cpp', '/content/PyTorch-Encoding/encoding/lib/cpu/operator.cpp', '/content/PyTorch-Encoding/encoding/lib/cpu/roi_align_cpu.cpp', '/content/PyTorch-Encoding/encoding/lib/cpu/syncbn_cpu.cpp', '/content/PyTorch-Encoding/encoding/lib/cpu/rectify_cpu.cpp']
# ...

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !python /content/PyTorch-Encoding/experiments/segmentation/test.py --dataset citys --resume "/content/drive/MyDrive/ResNeSt4808/runs/citys/deeplab/resnest50/model_480_8_50/model_best.pth.tar" --model deeplab --aux --backbone resnest50 --eval
